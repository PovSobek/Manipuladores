# %% [markdown]
# <a href="https://colab.research.google.com/github/PovSobek/Manipuladores/blob/main/02_Cinematica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='steelblue'> Introducción a la cinemática en Robótica </font>
#
# **Material desarrollado por Vicente Esteve-Sala**
#
# ![](https://drive.google.com/thumbnail?id=1GrzpXe8zsvQwyY7zTw87VCG4c14sHTvt&sz=w800)
#
# **Fecha última edición**: 13/10/2025
#
# **Licencia**:
# <small> © 2025 by <a href="https://cvnet.cpd.ua.es/curriculum-breve/es/esteve-sala-vicente-manuel/283903">Vicente Esteve-Sala</a> is licensed under <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/">CC BY-NC-SA 4.0       </a><small><a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br /></small>
#
# Al usar estos contenidos, aceptas los términos de uso, propiedad intelectual y la política de privacidad de la UA.
#
# **Advertencia**: Todo el contenido y cálculos son con fines educativos y no deben usarse en entornos profesionales ya que precisan de un estudio en profundidad y pueden contener errores.

# %% [markdown]
# ## Bibliotecas Esenciales: NumPy y Matplotlib
#
# En robótica, constantemente trabajamos con matemáticas (vectores, matrices) y necesitamos visualizar nuestros resultados. Dos bibliotecas son fundamentales para esto:
#
# * **NumPy:** Es la biblioteca principal para la computación científica en Python. Nos permite trabajar con arrays y realizar operaciones matemáticas complejas de forma muy eficiente.
# * **Matplotlib:** Es la biblioteca más popular para crear gráficos y visualizaciones en Python. 📈
#
# Vamos a importarlas en la siguiente celda.

# %%
# Importamos las bibliotecas y les damos un "alias" más corto para usarlas fácilmente.
import numpy as np
import matplotlib.pyplot as plt

print("Bibliotecas NumPy y Matplotlib cargadas correctamente.")

# %% [markdown]
# ## Ejercicio Práctico: Cinemática de un Brazo Robot Sencillo
#
# Vamos a resolver un problema clásico: calcular la posición final (x, y) de la punta de un brazo robot de 2 articulaciones (también llamado efector final) a partir de los ángulos de sus motores.
#
# **El Problema:**
# Tenemos un brazo robot con dos eslabones de longitudes **L₁** y **L₂**. Sus motores controlan los ángulos **θ₁** y **θ₂**.
#
#
# Las ecuaciones para encontrar la posición (x, y) son:
# $$ x = L_1 \cos(\theta_1) + L_2 \cos(\theta_1 + \theta_2) $$
# $$ y = L_1 \sin(\theta_1) + L_2 \sin(\theta_1 + \theta_2) $$
#
# **Ejercicio Práctico**

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- DATOS DEL ROBOT ---
L1 = 1.0  # Longitud del primer eslabón (metros)
L2 = 0.8  # Longitud del segundo eslabón (metros)

# Ángulos de las articulaciones (en grados)
theta1_grados = 45.0
theta2_grados = 30.0

# --- CÁLCULOS ---
# NumPy necesita los ángulos en radianes, así que primero los convertimos.
theta1_rad = np.deg2rad(theta1_grados)
theta2_rad = np.deg2rad(theta2_grados)


# ▼▼▼ TU CÓDIGO AQUÍ ▼▼▼

# 1. Calcula la posición de la primera articulación (el "codo")
#    Esto es necesario para poder dibujar el primer eslabón.
x1 = 0 # Reemplaza el 0 con la fórmula correcta
y1 = 0 # Reemplaza el 0 con la fórmula correcta

# 2. Calcula la posición final de la pinza (efector final)
#    Se parte de la posición del codo (x1, y1) y se añade el segundo eslabón.
x_final = 0 # Reemplaza el 0 con la fórmula correcta
y_final = 0 # Reemplaza el 0 con la fórmula correcta

# ▲▲▲ FIN DE TU CODIGO ▲▲▲


print(f"La posición del efector final es: (x={x_final:.2f}, y={y_final:.2f})")

# --- VISUALIZACIÓN ---
plt.figure()
# Dibujamos los eslabones del brazo
plt.plot([0, x1], [0, y1], 'r-o', linewidth=3, markersize=10, label='Eslabón 1')
plt.plot([x1, x_final], [y1, y_final], 'b-o', linewidth=3, markersize=10, label='Eslabón 2')

# Configuramos el gráfico
plt.title('Brazo Robot de 2-DOF')
plt.xlabel('Coordenada X (m)')
plt.ylabel('Coordenada Y (m)')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.gca().set_aspect('equal', adjustable='box') # Para que las proporciones sean realistas
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Tu Tarea:**
# 1. Completa el código en la celda anterior para calcular `x` e `y` usando esas fórmulas, en dos posiciones diferentes.
# 2. Realiza capturas de pantalla de las dos posiciones
# 3. Entrega en un pdf las capturas de pantallas y el código generado
